# %% [markdown]
# # 🚀 Aira AI Dual-System Training Notebook v2 (Google Colab)
#
# > **AiraAI**: High-Efficiency Dual-System Architecture (System 1 Non-Autoregressive Triage + System 2 MCTS Reasoning) with Live Web UI Dashboard & Google Drive Checkpoint Persistence.

# %%
# 1. Check GPU Hardware Allocation
# !nvidia-smi

# %%
# 2. Clone Repository & Install Dependencies
# !git clone https://github.com/DarkKingTg/AiraPiX.git
# %cd AiraPiX
# !git checkout codex/aira-training-setup
# !pip install -r requirements.txt

# %%
# 3. Run Aira Dual-System Training Loop v2 with Live Web UI Dashboard (Port 7860)
# !python colab/run_colab_training_v2.py \
  --preset 8b \
  --max-steps 1000 \
  --micro-batch-size 2 \
  --grad-accum 16 \
  --peak-lr 3e-4 \
  --port 7860 \
  --mount-drive \
  --load-in-4bit \
  --use-qlora

# %%
# 4. Run Step-by-Step Cognitive Debug Brain Processor
# !python scripts/debug_aira_brain.py --prompt "Design and test Aira AGI dual-process self-improvement architecture."

# %%
# 5. Run Custom Benchmark Suite
# !python scripts/run_aira_benchmarks.py --model-tag "AiraPiX-8B-DualSystem-v1"
